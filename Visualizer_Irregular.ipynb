# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2        # only used for loading the image, you can use anything that returns the image as a np.ndarray
import keras
import keras.preprocessing.image
import h5py
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D
import os
from keras.models import Sequential
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
irregular = cv2.imread("./Category1/Irregular/download (2).jpg")

# %%
plt.imshow(irregular)

# %%
irregular.shape
# Out:
# (232, 217, 3)

# %%
num_classes=3

# %%
model1 = Sequential()
model1.add(Conv2D(3,5,5, activation='tanh', input_shape=irregular.shape))

# %%
irr_batch = np.expand_dims(irregular,axis=0)
conv_irr = model.predict(irr_batch)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-6192ad289247> in <module>()
#       1 irr_batch = np.expand_dims(irregular,axis=0)
# ----> 2 conv_irr = model.predict(irr_batch)
#
# C:\Users\Diganta\Anaconda\lib\site-packages\keras\models.py in predict(self, x, batch_size, verbose, steps)
#    1025             self.build()
#    1026         return self.model.predict(x, batch_size=batch_size, verbose=verbose,
# -> 1027                                   steps=steps)
#    1028
#    1029     def predict_on_batch(self, x):
#
# C:\Users\Diganta\Anaconda\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1780         x = _standardize_input_data(x, self._feed_input_names,
#    1781                                     self._feed_input_shapes,
# -> 1782                                     check_batch_axis=False)
#    1783         if self.stateful:
#    1784             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# C:\Users\Diganta\Anaconda\lib\site-packages\keras\engine\training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     118                             ': expected ' + names[i] + ' to have shape ' +
#     119                             str(shape) + ' but got array with shape ' +
# --> 120                             str(data_shape))
#     121     return data
#     122
#
# ValueError: Error when checking : expected conv2d_11_input to have shape (214, 236, 3) but got array with shape (232, 217, 3)

# %%
def visualize_irr(model, irregular):
    fig = plt.gcf()
    irr_batch = np.expand_dims(irregular,axis=0)
    conv_irr = model.predict(irr_batch)
    conv_irr = np.squeeze(conv_irr, axis=0)
    print (conv_irr.shape)
    plt.imshow(conv_irr)
    fig.savefig('3_filter_1st_layer_visuals.png')

# %%
visualize_irr(model1, irregular)
# Out:
# (228, 213, 3)

# %%
model2 = Sequential()
model2.add(Conv2D(1,5,5, activation='tanh', input_shape=irregular.shape))
model2.add(MaxPooling2D(pool_size=(5,5)))

# %%
def nice_galaxy_printer(model, irregular):
    fig = plt.gcf()
    irr_batch = np.expand_dims(irregular,axis=0)
    conv_irr2 = model.predict(irr_batch)

    conv_irr2 = np.squeeze(conv_irr2, axis=0)
    print (conv_irr2.shape)
    conv_irr2 = conv_irr2.reshape(conv_irr2.shape[:2])

    print (conv_irr2.shape)
    plt.imshow(conv_irr2)
    fig.savefig('1_filter_1st_layer_visuals_with_pooling.png')

# %%
nice_galaxy_printer(model2, irregular)
# Out:
# (45, 42, 1)
# (45, 42)
